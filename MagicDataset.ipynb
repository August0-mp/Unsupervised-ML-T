# %% [markdown]
# <a href="https://colab.research.google.com/github/August0-mp/Unsupervised-ML-T/blob/main/MagicDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# ## Data collection and first manipulations
#
# ---

# %%
magic_gamma_telescope = fetch_ucirepo(id=159)

X = magic_gamma_telescope.data.features
y = magic_gamma_telescope.data.targets

df = pd.concat([X, y], axis=1)
df['class'] = df['class'].map({'g': 0, 'h': 1})
df.head()

feature_list = list(X.columns)

# %% [markdown]
# ## Visualization of the data
#
# ---

# %%
for feature in feature_list:
    plt.hist(df[df['class']==0][feature], bins=30, alpha=0.5, label='gamma')
    plt.hist(df[df['class']==1][feature], bins=30, alpha=0.5, label='hadron')
    plt.title(feature)
    plt.ylabel("Probability")
    plt.xlabel(feature)
    plt.legend()
    plt.show()

# %% [markdown]
# #Train, validation, test datasets
#
# ---

# %%
# Create the train, test and validation datasets with a random df sample
# 60% for training, 20% for validation and the remaining 20% to testing

train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])
# Out:
# /usr/local/lib/python3.11/dist-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# We have to

# %%
df
# Out:
#         fLength    fWidth   fSize   fConc  fConc1     fAsym   fM3Long  \
# 0       28.7967   16.0021  2.6449  0.3918  0.1982   27.7004   22.0110
# 1       31.6036   11.7235  2.5185  0.5303  0.3773   26.2722   23.8238
# 2      162.0520  136.0310  4.0612  0.0374  0.0187  116.7410  -64.8580
# 3       23.8172    9.5728  2.3385  0.6147  0.3922   27.2107   -6.4633
# 4       75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277   28.5525
# ...         ...       ...     ...     ...     ...       ...       ...
# 19015   21.3846   10.9170  2.6161  0.5857  0.3934   15.2618   11.5245
# 19016   28.9452    6.7020  2.2672  0.5351  0.2784   37.0816   13.1853
# 19017   75.4455   47.5305  3.4483  0.1417  0.0549   -9.3561   41.0562
# 19018  120.5135   76.9018  3.9939  0.0944  0.0683    5.8043  -93.5224
# 19019  187.1814   53.0014  3.2093  0.2876  0.1539 -167.3125 -168.4558
#
#        fM3Trans   fAlpha     fDist  class
# 0       -8.2027  40.0920   81.8828      0
# ...
